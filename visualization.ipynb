# %%
import pandas as pd
import plotly.express as px
import os

# %%
def plot_data_from_logs(log_folder):
    # Assuming the logs are in CSV format with the provided header
    all_data = []
    # List all log files in the directory
    for log_file in os.listdir(log_folder):
        file_path = os.path.join(log_folder, log_file)
        if os.path.isfile(file_path) and file_path.endswith('.log'):
            data = pd.read_csv(file_path, index_col=None, header=0)
            all_data.append(data)
    
    # Concatenate all dataframes into one
    df = pd.concat(all_data, axis=0, ignore_index=True)
    
    # Plot each column except the first few that are identifiers or non-numeric
    numeric_columns = df.columns[6:]  # adjust based on your data structure
    for column in numeric_columns:
        fig = px.line(df, x=df.index, y=column, title=f'{log_folder.split("/")[-1]} - {column}')
        fig.show()

# %%
# Paths to the log directories
vfat_logs = './vfat/ondemand'
xfs_logs = './xfs/ondemand'

plot_data_from_logs(vfat_logs)
plot_data_from_logs(xfs_logs)
